# %%
import pandas as pd
import seaborn as sea

# %%
dati_nazione = pd.read_csv('data/dati-andamento-nazionale/dpc-covid19-ita-andamento-nazionale.csv', sep=',', header=None)
dati_regioni = pd.read_csv('data/dati-regioni/dpc-covid19-ita-regioni.csv', sep=',', header=None)
dati_province = pd.read_csv('data/dati-province/dpc-covid19-ita-province.csv', sep=',', header=None)

# %%
dati_nazione
# Out:
#                      0      1                       2                  3   \
# 0                  data  stato  ricoverati_con_sintomi  terapia_intensiva
# 1   2020-02-24 18:00:00    ITA                     101                 26
# 2   2020-02-25 18:00:00    ITA                     114                 35
# 3   2020-02-26 18:00:00    ITA                     128                 36
# 4   2020-02-27 18:00:00    ITA                     248                 56
# 5   2020-02-28 18:00:00    ITA                     345                 64
# 6   2020-02-29 18:00:00    ITA                     401                105
# 7   2020-03-01 18:00:00    ITA                     639                140
# 8   2020-03-02 18:00:00    ITA                     742                166
# 9   2020-03-03 18:00:00    ITA                    1034                229
# 10  2020-03-04 18:00:00    ITA                    1346                295
# 11  2020-03-05 18:00:00    ITA                    1790                351
# ...

# %%
import plotly.express as px
df = px.data.gapminder()
#fig = px.scatter_geo(df, locations="iso_alpha", color="continent",
#                     hover_name="country", size="pop",
#                     animation_frame="year",
#                     projection="natural earth")
#fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-f69c156376fb> in <module>
# ----> 1 import plotly.express as px
#       2 df = px.data.gapminder()
#       3 #fig = px.scatter_geo(df, locations="iso_alpha", color="continent",
#       4 #                     hover_name="country", size="pop",
#       5 #                     animation_frame="year",
#
# ModuleNotFoundError: No module named 'plotly'
